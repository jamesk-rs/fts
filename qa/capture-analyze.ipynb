# %% [markdown]
# * This notebook contains RX-side commands for demo 3b
# * See generate.ipynb notebook for matching commands on TX side
# * Reports are in data/testNN-*/report.html

# %% [markdown]
# ## TEST 30 - VALIDATE NOSYNC P0 J0

# %%
src/cli.py capture-edges -g 6.5 -d 600 data/test30-validate-nosync-p+0-j+0
# Out:
# Capturing edges to data/test30-validate-nosync-p+0-j+0/
#   Duration: 600.0s
#   Sample rate: 10.0 MSps
#   Pulse freq: 2000 Hz
#   Threshold: 0.4
#   Skip: 0.1s (1000000 samples)
#   Min distance: 2000 samples
#   Algorithm: crossing
# Connecting to RX USRP at 192.168.10.2...
# [INFO] [UHD] linux; GNU C++ version 13.2.0; Boost_108300; UHD_4.6.0.0+ds1-5.1ubuntu0.24.04.1
# [INFO] [USRP2] Opening a USRP2/N-Series device...
# [INFO] [USRP2] Current recv frame size: 1472 bytes
# [INFO] [USRP2] Current send frame size: 1472 bytes
# [INFO] [USRP2] Detecting internal GPSDO....
# [INFO] [GPS] Found an internal GPSDO: Jackson-Labs, FireFly , Firmware Rev 0.928
# [INFO] [USRP2] Setting references to the internal GPSDO
#   Clock source: gpsdo
#   Time source: gpsdo
#   Sample rate: 10.0 MSps
#   Frequency: 0.0 MHz
#   Gain: 6.5 dB
# [  3.6s] 0.1M samples, edges: A=0, B=0
# [  4.6s] 21.1M samples, edges: A=8040, B=8040
# [  5.6s] 31.2M samples, edges: A=12080, B=12080
# ...

# %%
src/cli.py analyze-edges data/test30-validate-nosync-p+0-j+0
# Out:
# Analyzing edges from data/test30-validate-nosync-p+0-j+0/
#   Sample rate: 10.0 MSps
#   Pulse freq: 2000 Hz
#   Reference (ch0): 2399598 edges
#   Target (ch1): 2399598 edges
#
# Matching edges (max delay: 50000ns)...
#   Filtered edges: ref=1199799, target=1199799
#   Matched: 1245799, Rejected: 0
#
# Jitter Statistics (n=1199799)
#   Mean:   +1.975 ns
#   Std:    0.383 ns
#   Min:    1.202 ns
#   Max:    3.666 ns
#   P50:    ±0.245 ns
#   P95:    ±0.788 ns
#   P99:    ±1.105 ns
#
# Saved 1199799 delays to data/test30-validate-nosync-p+0-j+0/delays.bin
#
# Period Analysis:
#   Channel A: Period: 500.000 ± 0.000 µs (1999.999238 Hz, -0.4 ppm)
#   Channel B: Period: 500.000 ± 0.000 µs (1999.999238 Hz, -0.4 ppm)
#   Frequency skew: -0.000 ppm (-0.0 ns/s)
# Plots saved to data/test30-validate-nosync-p+0-j+0/
# Open data/test30-validate-nosync-p+0-j+0/report.html in browser for full report

# %% [markdown]
# ## TEST 31 - VALIDATE P0 J0

# %%
src/cli.py capture-edges -g 6.5 -d 600 data/test31-validate-sync-p+0-j+0
# Out:
# Capturing edges to data/test31-validate-sync-p+0-j+0/
#   Duration: 600.0s
#   Sample rate: 10.0 MSps
#   Pulse freq: 2000 Hz
#   Threshold: 0.4
#   Skip: 0.1s (1000000 samples)
#   Min distance: 2000 samples
#   Algorithm: crossing
# Connecting to RX USRP at 192.168.10.2...
# [INFO] [UHD] linux; GNU C++ version 13.2.0; Boost_108300; UHD_4.6.0.0+ds1-5.1ubuntu0.24.04.1
# [INFO] [USRP2] Opening a USRP2/N-Series device...
# [INFO] [USRP2] Current recv frame size: 1472 bytes
# [INFO] [USRP2] Current send frame size: 1472 bytes
# [INFO] [USRP2] Detecting internal GPSDO....
# [INFO] [GPS] Found an internal GPSDO: Jackson-Labs, FireFly , Firmware Rev 0.928
# [INFO] [USRP2] Setting references to the internal GPSDO
#   Clock source: gpsdo
#   Time source: gpsdo
#   Sample rate: 10.0 MSps
#   Frequency: 0.0 MHz
#   Gain: 6.5 dB
# [  4.0s] 0.1M samples, edges: A=0, B=0
# [  5.0s] 24.9M samples, edges: A=9560, B=9560
# [  6.0s] 35.0M samples, edges: A=13600, B=13600
# ...

# %%
src/cli.py analyze-edges data/test31-validate-sync-p+0-j+0
# Out:
# Analyzing edges from data/test31-validate-sync-p+0-j+0/
#   Sample rate: 10.0 MSps
#   Pulse freq: 2000 Hz
#   Reference (ch0): 2399600 edges
#   Target (ch1): 2399600 edges
#
# Matching edges (max delay: 50000ns)...
#   Filtered edges: ref=1199800, target=1199800
#   Matched: 1245806, Rejected: 6
#
# Jitter Statistics (n=1199800)
#   Mean:   +2.307 ns
#   Std:    0.063 ns
#   Min:    2.017 ns
#   Max:    2.602 ns
#   P50:    ±0.043 ns
#   P95:    ±0.127 ns
#   P99:    ±0.161 ns
#
# Saved 1199800 delays to data/test31-validate-sync-p+0-j+0/delays.bin
#
# Period Analysis:
#   Channel A: Period: 500.000 ± 0.000 µs (2000.000000 Hz, +0.0 ppm)
#   Channel B: Period: 500.000 ± 0.000 µs (2000.000000 Hz, +0.0 ppm)
#   Frequency skew: +0.000 ppm (+0.0 ns/s)
# Plots saved to data/test31-validate-sync-p+0-j+0/
# Open data/test31-validate-sync-p+0-j+0/report.html in browser for full report

# %% [markdown]
# ## TEST 32 - VALIDATE P1000 J250

# %%
src/cli.py capture-edges -g 6.5 data/test32-validate-p+1000-j+250
# Out:
# Capturing edges to data/test32-validate-p+1000-j+250/
#   Duration: 60s
#   Sample rate: 10.0 MSps
#   Pulse freq: 2000 Hz
#   Threshold: 0.4
#   Skip: 0.1s (1000000 samples)
#   Min distance: 2000 samples
#   Algorithm: crossing
# Connecting to RX USRP at 192.168.10.2...
# [INFO] [UHD] linux; GNU C++ version 11.2.0; Boost_107400; UHD_4.1.0.5-3
# [INFO] [USRP2] Opening a USRP2/N-Series device...
# [INFO] [USRP2] Current recv frame size: 1472 bytes
# [INFO] [USRP2] Current send frame size: 1472 bytes
# [INFO] [USRP2] Detecting internal GPSDO....
# [INFO] [GPS] Found an internal GPSDO: Jackson-Labs, FireFly , Firmware Rev 0.928
# [INFO] [USRP2] Setting references to the internal GPSDO
#   Clock source: gpsdo
#   Time source: gpsdo
#   Sample rate: 10.0 MSps
#   Frequency: 0.0 MHz
#   Gain: 6.5 dB
# [  4.0s] 0.1M samples, edges: A=0, B=0
# [  5.0s] 25.4M samples, edges: A=9760, B=9760
# [  6.0s] 35.5M samples, edges: A=13800, B=13800
# [  7.1s] 45.6M samples, edges: A=17840, B=17840
# ...

# %%
src/cli.py analyze-edges data/test32-validate-p+1000-j+250
# Out:
# Analyzing edges from data/test32-validate-p+1000-j+250/
#   Sample rate: 10.0 MSps
#   Pulse freq: 2000 Hz
#   Reference (ch0): 239600 edges
#   Target (ch1): 239600 edges
#
# Matching edges (max delay: 50000ns)...
#   Filtered edges: ref=119800, target=119800
#   Matched: 123801, Rejected: 1
#
# Jitter Statistics (n=119800)
#   Mean:   +1001.958 ns
#   Std:    249.422 ns
#   Min:    139.740 ns
#   Max:    1799.951 ns
#   P50:    ±167.644 ns
#   P95:    ±488.466 ns
#   P99:    ±646.092 ns
#
# Saved 119800 delays to data/test32-validate-p+1000-j+250/delays.bin
#
# Period Analysis:
#   Channel A: Period: 500.000 ± 0.000 µs (2000.000000 Hz, +0.0 ppm)
#   Channel B: Period: 500.000 ± 0.355 µs (2000.000015 Hz, +0.0 ppm)
#   Frequency skew: +0.008 ppm (+7.7 ns/s)
# Plots saved to data/test32-validate-p+1000-j+250/
# Open data/test32-validate-p+1000-j+250/report.html in browser for full report

# %% [markdown]
# ## TEST 33 - VALIDATE P-20 J20

# %%
src/cli.py capture-edges -g 6.5 data/test33-validate-p-20-j+20
# Out:
# Capturing edges to data/test33-validate-p-20-j+20/
#   Duration: 60s
#   Sample rate: 10.0 MSps
#   Pulse freq: 2000 Hz
#   Threshold: 0.4
#   Skip: 0.1s (1000000 samples)
#   Min distance: 2000 samples
#   Algorithm: crossing
# Connecting to RX USRP at 192.168.10.2...
# [INFO] [UHD] linux; GNU C++ version 11.2.0; Boost_107400; UHD_4.1.0.5-3
# [INFO] [USRP2] Opening a USRP2/N-Series device...
# [INFO] [USRP2] Current recv frame size: 1472 bytes
# [INFO] [USRP2] Current send frame size: 1472 bytes
# [INFO] [USRP2] Detecting internal GPSDO....
# [INFO] [GPS] Found an internal GPSDO: Jackson-Labs, FireFly , Firmware Rev 0.928
# [INFO] [USRP2] Setting references to the internal GPSDO
#   Clock source: gpsdo
#   Time source: gpsdo
#   Sample rate: 10.0 MSps
#   Frequency: 0.0 MHz
#   Gain: 6.5 dB
# [  3.7s] 0.1M samples, edges: A=0, B=0
# [  4.7s] 21.7M samples, edges: A=8280, B=8280
# [  5.7s] 31.8M samples, edges: A=12320, B=12320
# [  6.7s] 41.9M samples, edges: A=16360, B=16360
# ...

# %%
src/cli.py analyze-edges data/test33-validate-p-20-j+20
# Out:
# Analyzing edges from data/test33-validate-p-20-j+20/
#   Sample rate: 10.0 MSps
#   Pulse freq: 2000 Hz
#   Reference (ch0): 239600 edges
#   Target (ch1): 239600 edges
#
# Matching edges (max delay: 50000ns)...
#   Filtered edges: ref=119800, target=119800
#   Matched: 123800, Rejected: 0
#
# Jitter Statistics (n=119800)
#   Mean:   -9.908 ns
#   Std:    17.807 ns
#   Min:    -81.082 ns
#   Max:    61.814 ns
#   P50:    ±9.794 ns
#   P95:    ±38.729 ns
#   P99:    ±51.437 ns
#
# Saved 119800 delays to data/test33-validate-p-20-j+20/delays.bin
#
# Period Analysis:
#   Channel A: Period: 500.000 ± 0.000 µs (2000.000000 Hz, +0.0 ppm)
#   Channel B: Period: 500.000 ± 0.025 µs (1999.999999 Hz, -0.0 ppm)
#   Frequency skew: -0.000 ppm (-0.3 ns/s)

# %% [markdown]
# ## TEST 34 - VALIDATE P-20 J20 (8 hours)

# %%
src/cli.py capture-edges -d `expr 8 \* 60 \* 60` -g 6.5 data/test34-validate-p-20-j+20-long
# Out:
# Capturing edges to data/test34-validate-p-20-j+20-long/
#   Duration: 28800.0s
#   Sample rate: 10.0 MSps
#   Pulse freq: 2000 Hz
#   Threshold: 0.4
#   Skip: 0.1s (1000000 samples)
#   Min distance: 2000 samples
#   Algorithm: crossing
# Connecting to RX USRP at 192.168.10.2...
# [INFO] [UHD] linux; GNU C++ version 11.2.0; Boost_107400; UHD_4.1.0.5-3
# [INFO] [USRP2] Opening a USRP2/N-Series device...
# [INFO] [USRP2] Current recv frame size: 1472 bytes
# [INFO] [USRP2] Current send frame size: 1472 bytes
# [INFO] [USRP2] Detecting internal GPSDO....
# [INFO] [GPS] Found an internal GPSDO: Jackson-Labs, FireFly , Firmware Rev 0.928
# [INFO] [USRP2] Setting references to the internal GPSDO
#   Clock source: gpsdo
#   Time source: gpsdo
#   Sample rate: 10.0 MSps
#   Frequency: 0.0 MHz
#   Gain: 6.5 dB
# [  4.3s] 0.1M samples, edges: A=0, B=0
# D[  5.3s] 22.8M samples, edges: A=8712, B=8712
# [  6.3s] 35.2M samples, edges: A=13672, B=13672
# ...

# %%
src/cli.py analyze-edges data/test34-validate-p-20-j+20-long

# %% [markdown]
# ## XXX stream

# %%
src/cli.py stream
# Out:
# Streaming capture with live jitter analysis...
#   Duration: 60s
#   Sample rate: 10.0 MSps
#   Pulse freq: 2000 Hz
#   Threshold: 0.4
# Connecting to RX USRP at 192.168.10.2...
# [INFO] [UHD] linux; GNU C++ version 13.2.0; Boost_108300; UHD_4.6.0.0+ds1-5.1ubuntu0.24.04.1
# [INFO] [USRP2] Opening a USRP2/N-Series device...
# [INFO] [USRP2] Current recv frame size: 1472 bytes
# [INFO] [USRP2] Current send frame size: 1472 bytes
# [INFO] [USRP2] Detecting internal GPSDO....
# [INFO] [GPS] Found an internal GPSDO: Jackson-Labs, FireFly , Firmware Rev 0.928
# [INFO] [USRP2] Setting references to the internal GPSDO
#   Clock source: gpsdo
#   Time source: gpsdo
#   Sample rate: 10.0 MSps
#   Frequency: 0.0 MHz
#   Gain: 0.0 dB
# [  3.5s] 0.1M samples, edges: A=0, B=0
# [  4.5s] 20.0M samples, 3800 edges, mean=-29.3ns, std=13.4ns, min=-69.0ns, max=3.9ns
# [  5.5s] 30.0M samples, 5800 edges, mean=-24.7ns, std=14.3ns, min=-69.0ns, max=13.9ns
# ...
