# %%
src/cli.py capture-edges data/test51-floor2
# Out:
# Capturing edges to data/test51-floor2/
#   Duration: 60s
#   Sample rate: 10.0 MSps
#   Pulse freq: 2000 Hz
#   Threshold: 0.4
#   Skip: 0.1s (1000000 samples)
#   Min distance: 2000 samples
#   Algorithm: crossing
# Connecting to RX USRP at 192.168.10.2...
# [INFO] [UHD] linux; GNU C++ version 13.2.0; Boost_108300; UHD_4.6.0.0+ds1-5.1ubuntu0.24.04.1
# [INFO] [USRP2] Opening a USRP2/N-Series device...
# [INFO] [USRP2] Current recv frame size: 1472 bytes
# [INFO] [USRP2] Current send frame size: 1472 bytes
# [INFO] [USRP2] Detecting internal GPSDO....
# [INFO] [GPS] Found an internal GPSDO: Jackson-Labs, FireFly , Firmware Rev 0.928
# [INFO] [USRP2] Setting references to the internal GPSDO
#   Clock source: gpsdo
#   Time source: gpsdo
#   Sample rate: 10.0 MSps
#   Frequency: 0.0 MHz
#   Gain: 0.0 dB
# [  3.6s] 0.1M samples, edges: A=0, B=0
# [  4.6s] 21.1M samples, edges: A=8040, B=8040
# [  5.6s] 31.1M samples, edges: A=12040, B=12040
# ...

# %%
src/cli.py stream
# Out:
# Streaming capture with live jitter analysis...
#   Duration: 60s
#   Sample rate: 10.0 MSps
#   Pulse freq: 2000 Hz
#   Threshold: 0.4
# Connecting to RX USRP at 192.168.10.2...
# [INFO] [UHD] linux; GNU C++ version 13.2.0; Boost_108300; UHD_4.6.0.0+ds1-5.1ubuntu0.24.04.1
# [INFO] [USRP2] Opening a USRP2/N-Series device...
# [INFO] [USRP2] Current recv frame size: 1472 bytes
# [INFO] [USRP2] Current send frame size: 1472 bytes
# [INFO] [USRP2] Detecting internal GPSDO....
# [INFO] [GPS] Found an internal GPSDO: Jackson-Labs, FireFly , Firmware Rev 0.928
# [INFO] [USRP2] Setting references to the internal GPSDO
#   Clock source: gpsdo
#   Time source: gpsdo
#   Sample rate: 10.0 MSps
#   Frequency: 0.0 MHz
#   Gain: 0.0 dB
# [  3.7s] 0.1M samples, edges: A=0, B=0
# [  4.7s] 22.0M samples, 4200 edges, mean=-112.5ns, std=12.4ns, min=-150.7ns, max=-68.9ns
# [  5.7s] 32.1M samples, 6220 edges, mean=-98.9ns, std=32.1ns, min=-150.7ns, max=-1.9ns
# ...

# %%
src/cli.py analyze-edges data/test51-floor2
# Out:
# Analyzing edges from data/test51-floor2/
#   Sample rate: 10.0 MSps
#   Pulse freq: 2000 Hz
#   Reference (ch0): 239603 edges
#   Target (ch1): 239603 edges
#
# Matching edges (max delay: 50000ns)...
#   Filtered edges: ref=119801, target=119801
#   Matched: 123803, Rejected: 0
#
# Jitter Statistics (n=119801)
#   Mean:   -59.414 ns
#   Std:    35.735 ns
#   Min:    -142.682 ns
#   Max:    49.267 ns
#   P50:    ±25.379 ns
#   P95:    ±70.052 ns
#   P99:    ±84.170 ns
#
# Saved 119801 delays to data/test51-floor2/delays.bin
#
# Period Analysis:
#   Channel A: Period: 499.995 ± 0.011 µs (2000.021165 Hz, +10.6 ppm)
#   Channel B: Period: 499.995 ± 0.010 µs (2000.021168 Hz, +10.6 ppm)
#   Frequency skew: +0.001 ppm (+1.5 ns/s)
# Plots saved to data/test51-floor2/
# Open data/test51-floor2/report.html in browser for full report
