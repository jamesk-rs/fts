# %% [markdown]
# #### tried capturing 1h, somethign went wrong - cant make report

# %%
src/cli.py capture-edges data/test53-floor2-1h -d `expr 1 \* 60 \* 60`
# Out:
# Capturing edges to data/test53-floor2-1h/
#   Duration: 3600.0s
#   Sample rate: 10.0 MSps
#   Pulse freq: 2000 Hz
#   Threshold: 0.4
#   Skip: 0.1s (1000000 samples)
#   Min distance: 2000 samples
#   Algorithm: crossing
# Connecting to RX USRP at 192.168.10.2...
# [INFO] [UHD] linux; GNU C++ version 13.2.0; Boost_108300; UHD_4.6.0.0+ds1-5.1ubuntu0.24.04.1
# [INFO] [USRP2] Opening a USRP2/N-Series device...
# [INFO] [USRP2] Current recv frame size: 1472 bytes
# [INFO] [USRP2] Current send frame size: 1472 bytes
# [INFO] [USRP2] Detecting internal GPSDO....
# [INFO] [GPS] Found an internal GPSDO: Jackson-Labs, FireFly , Firmware Rev 0.928
# [INFO] [USRP2] Setting references to the internal GPSDO
#   Clock source: gpsdo
#   Time source: gpsdo
#   Sample rate: 10.0 MSps
#   Frequency: 0.0 MHz
#   Gain: 0.0 dB
# [  3.9s] 0.1M samples, edges: A=0, B=0
# [  4.9s] 24.8M samples, edges: A=9520, B=9520
# [  5.9s] 34.8M samples, edges: A=13520, B=13520
# ...

# %%
src/cli.py analyze-edges data/test53-floor2-1h
# Out:
# Analyzing edges from data/test53-floor2-1h/
#   Sample rate: 10.0 MSps
#   Pulse freq: 2000 Hz
#   Reference (ch0): 10114930 edges
#   Target (ch1): 14109182 edges
#
# Matching edges (max delay: 50000ns)...
# Traceback (most recent call last):
#   File "/home/abb/Documents/dvp/fts/qa/src/cli.py", line 1460, in <module>
#     p_analyze_edges.add_argument('-o', '--output', help='Output directory (default: same as input)')
#              ^^^^^^
#   File "/home/abb/Documents/dvp/fts/qa/src/cli.py", line 1456, in main
#     # analyze-edges command
#            ^^^^^^^^^^^^^^^
#   File "/home/abb/Documents/dvp/fts/qa/src/cli.py", line 1316, in cmd_analyze_edges
#     output_dir,
#            ^^^^^
#   File "/home/abb/Documents/dvp/fts/qa/src/cli.py", line 926, in analyze_edge_files
#     periods_a_sampled.append(p)
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/abb/Documents/dvp/fts/qa/src/analyze/streaming.py", line 101, in match
#     dist = abs(target_times[i] - ref_time)
# ...

# %% [markdown]
# #### another quick test, apparently bad data

# %%
src/cli.py capture-edges data/test54-floor2-1m
# Out:
# Capturing edges to data/test54-floor2-1m/
#   Duration: 60s
#   Sample rate: 10.0 MSps
#   Pulse freq: 2000 Hz
#   Threshold: 0.4
#   Skip: 0.1s (1000000 samples)
#   Min distance: 2000 samples
#   Algorithm: crossing
# Connecting to RX USRP at 192.168.10.2...
# [INFO] [UHD] linux; GNU C++ version 13.2.0; Boost_108300; UHD_4.6.0.0+ds1-5.1ubuntu0.24.04.1
# [INFO] [USRP2] Opening a USRP2/N-Series device...
# [INFO] [USRP2] Current recv frame size: 1472 bytes
# [INFO] [USRP2] Current send frame size: 1472 bytes
# [INFO] [USRP2] Detecting internal GPSDO....
# [INFO] [GPS] Found an internal GPSDO: Jackson-Labs, FireFly , Firmware Rev 0.928
# [INFO] [USRP2] Setting references to the internal GPSDO
#   Clock source: gpsdo
#   Time source: gpsdo
#   Sample rate: 10.0 MSps
#   Frequency: 0.0 MHz
#   Gain: 0.0 dB
# [  3.6s] 0.1M samples, edges: A=0, B=0
# [  4.6s] 21.2M samples, edges: A=8080, B=6784
# [  5.6s] 31.2M samples, edges: A=12080, B=10784
# ...

# %%
src/cli.py analyze-edges data/test54-floor2-1m
# Out:
# Analyzing edges from data/test54-floor2-1m/
#   Sample rate: 10.0 MSps
#   Pulse freq: 2000 Hz
#   Loading FTM log: data/test54-floor2-1m/slave1.log
#     slave1: 616 ok, 0 failed
#   Loading FTM log: data/test54-floor2-1m/slave2.log
#     slave2: 329 ok, 288 failed
#   Reference (ch0): 260482 edges
#   Target (ch1): 238306 edges
#   Auto-skipping 0.324s to align channels
#
# Matching edges (max delay: 50000ns)...
#   Filtered edges: ref=128944, target=119153
#   Matched: 100993, Rejected: 31953
#
# Jitter Statistics (n=100993)
#   Mean:   +78.327 ns
#   Std:    68.180 ns
#   Min:    -9392.242 ns
#   Max:    242.249 ns
#   P50:    ±50.705 ns
#   P95:    ±108.975 ns
#   P99:    ±130.358 ns
#
# Saved 100993 delays to data/test54-floor2-1m/delays.bin
#
# Period Analysis:
#   Channel A: Period: 462.027 ± 13633.617 µs (2164.374640 Hz, +75945.6 ppm)
#   Channel B: Period: 499.995 ± 0.029 µs (2000.020138 Hz, +10.1 ppm)
#   Frequency skew: -82176.423 ppm (-82176423.2 ns/s)
# ...

# %%
src/cli.py stream
# Out:
# Streaming capture with live jitter analysis...
#   Duration: 60s
#   Sample rate: 10.0 MSps
#   Pulse freq: 2000 Hz
#   Threshold: 0.4
# Connecting to RX USRP at 192.168.10.2...
# [INFO] [UHD] linux; GNU C++ version 13.2.0; Boost_108300; UHD_4.6.0.0+ds1-5.1ubuntu0.24.04.1
# [INFO] [USRP2] Opening a USRP2/N-Series device...
# [INFO] [USRP2] Current recv frame size: 1472 bytes
# [INFO] [USRP2] Current send frame size: 1472 bytes
# [INFO] [USRP2] Detecting internal GPSDO....
# [INFO] [GPS] Found an internal GPSDO: Jackson-Labs, FireFly , Firmware Rev 0.928
# [INFO] [USRP2] Setting references to the internal GPSDO
#   Clock source: gpsdo
#   Time source: gpsdo
#   Sample rate: 10.0 MSps
#   Frequency: 0.0 MHz
#   Gain: 0.0 dB
# [  3.6s] 0.1M samples, edges: A=0, B=0
# [  4.6s] 21.1M samples, 4020 edges, mean=-186.8ns, std=26.3ns, min=-247.2ns, max=-124.7ns
# [  5.6s] 31.2M samples, 6040 edges, mean=-195.7ns, std=25.7ns, min=-250.8ns, max=-124.7ns
# ...

# %% [markdown]
# #### small capture, works ok

# %%
src/cli.py capture-edges data/test55-floor2-1m
# Out:
# Capturing edges to data/test55-floor2-1m/
#   Duration: 60s
#   Sample rate: 10.0 MSps
#   Pulse freq: 2000 Hz
#   Threshold: 0.4
#   Skip: 0.1s (1000000 samples)
#   Min distance: 2000 samples
#   Algorithm: crossing
# Connecting to RX USRP at 192.168.10.2...
# [INFO] [UHD] linux; GNU C++ version 13.2.0; Boost_108300; UHD_4.6.0.0+ds1-5.1ubuntu0.24.04.1
# [INFO] [USRP2] Opening a USRP2/N-Series device...
# [INFO] [USRP2] Current recv frame size: 1472 bytes
# [INFO] [USRP2] Current send frame size: 1472 bytes
# [INFO] [USRP2] Detecting internal GPSDO....
# [INFO] [GPS] Found an internal GPSDO: Jackson-Labs, FireFly , Firmware Rev 0.928
# [INFO] [USRP2] Setting references to the internal GPSDO
#   Clock source: gpsdo
#   Time source: gpsdo
#   Sample rate: 10.0 MSps
#   Frequency: 0.0 MHz
#   Gain: 0.0 dB
# [  3.9s] 0.1M samples, edges: A=0, B=0
# [  4.9s] 24.6M samples, edges: A=9440, B=0
# [  5.9s] 34.7M samples, edges: A=13480, B=0
# [  6.9s] 44.7M samples, edges: A=17480, B=0
# ...

# %%
src/cli.py analyze-edges data/test55-floor2-1m
# Out:
# Analyzing edges from data/test55-floor2-1m/
#   Sample rate: 10.0 MSps
#   Pulse freq: 2000 Hz
#   Loading FTM log: data/test55-floor2-1m/slave1.log
#     slave1: 415 ok, 80 failed
#   Loading FTM log: data/test55-floor2-1m/slave2.log
#     slave2: 483 ok, 11 failed
#   Reference (ch0): 239602 edges
#   Target (ch1): 42916 edges
#   Auto-skipping 49.171s to align channels
#
# Matching edges (max delay: 50000ns)...
#   Filtered edges: ref=21457, target=21458
#   Matched: 2001, Rejected: 21111
#
# Jitter Statistics (n=2001)
#   Mean:   +38.116 ns
#   Std:    12.642 ns
#   Min:    9.843 ns
#   Max:    71.792 ns
#   P50:    ±9.327 ns
#   P95:    ±23.409 ns
#   P99:    ±28.401 ns
#
# Saved 2001 delays to data/test55-floor2-1m/delays.bin
#
# Period Analysis:
#   Channel A: Period: 499.995 ± 0.011 µs (2000.020496 Hz, +10.2 ppm)
#   Channel B: Period: 499.992 ± 0.474 µs (2000.033431 Hz, +16.7 ppm)
#   Frequency skew: +6.467 ppm (+6467.4 ns/s)
# Plots saved to data/test55-floor2-1m/
# ...

# %%
src/cli.py stream
# Out:
# Streaming capture with live jitter analysis...
#   Duration: 60s
#   Sample rate: 10.0 MSps
#   Pulse freq: 2000 Hz
#   Threshold: 0.4
# Connecting to RX USRP at 192.168.10.2...
# [INFO] [UHD] linux; GNU C++ version 13.2.0; Boost_108300; UHD_4.6.0.0+ds1-5.1ubuntu0.24.04.1
# [INFO] [USRP2] Opening a USRP2/N-Series device...
# [INFO] [USRP2] Current recv frame size: 1472 bytes
# [INFO] [USRP2] Current send frame size: 1472 bytes
# [INFO] [USRP2] Detecting internal GPSDO....
# [INFO] [GPS] Found an internal GPSDO: Jackson-Labs, FireFly , Firmware Rev 0.928
# [INFO] [USRP2] Setting references to the internal GPSDO
#   Clock source: gpsdo
#   Time source: gpsdo
#   Sample rate: 10.0 MSps
#   Frequency: 0.0 MHz
#   Gain: 0.0 dB
# [  3.6s] 0.1M samples, edges: A=0, B=0
# [  4.6s] 20.9M samples, 3980 edges, mean=-178.3ns, std=18.2ns, min=-234.6ns, max=-132.3ns
# [  5.6s] 30.9M samples, 5980 edges, mean=-187.3ns, std=20.6ns, min=-240.9ns, max=-132.3ns
# ...
