# %%
docker ps -a
# Out:
# CONTAINER ID   IMAGE                    COMMAND                  CREATED          STATUS                    PORTS                                                                                      NAMES
# 6cada1c58542   fts-platform-rl_engine   "python -u main.py"      58 minutes ago   Up 37 minutes                                                                                                        fts-platform-rl_engine-1
# 38f1b1210ac4   grafana/grafana:10.4.3   "/run.sh"                58 minutes ago   Up 28 minutes             0.0.0.0:3000->3000/tcp, [::]:3000->3000/tcp                                                fts-platform-grafana-1
# 998abafc5849   influxdb:2.7             "/entrypoint.sh infl…"   58 minutes ago   Up 37 minutes (healthy)   0.0.0.0:8086->8086/tcp, [::]:8086->8086/tcp                                                fts-platform-influxdb-1
# ...
