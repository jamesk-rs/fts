# %%
N=607

# %%
DATADIR=data/test$N

# %%
src/cli.py capture-edges $DATADIR
# Out:
# Capturing edges to data/test607/
#   Duration: 60s
#   Sample rate: 10.0 MSps
#   Pulse freq: 2000 Hz
#   Threshold: 0.4
#   Skip: 0.1s (1000000 samples)
#   Min distance: 2000 samples
#   Algorithm: crossing
# Connecting to RX USRP at 192.168.10.2...
# [INFO] [UHD] linux; GNU C++ version 13.2.0; Boost_108300; UHD_4.6.0.0+ds1-5.1ubuntu0.24.04.1
# [INFO] [USRP2] Opening a USRP2/N-Series device...
# [INFO] [USRP2] Current recv frame size: 1472 bytes
# [INFO] [USRP2] Current send frame size: 1472 bytes
# [INFO] [USRP2] Detecting internal GPSDO....
# [INFO] [GPS] Found an internal GPSDO: Jackson-Labs, FireFly , Firmware Rev 0.928
# [INFO] [USRP2] Setting references to the internal GPSDO
#   Clock source: gpsdo
#   Time source: gpsdo
#   Sample rate: 10.0 MSps
#   Frequency: 0.0 MHz
#   Gain: 0.0 dB
# [  3.7s] 0.1M samples, edges: A=0, B=0
# [  4.7s] 21.9M samples, edges: A=8360, B=8360
# [  5.7s] 31.9M samples, edges: A=12360, B=12360
# [  6.7s] 41.9M samples, edges: A=16360, B=16360
# ...

# %%
src/cli.py analyze-edges $DATADIR
# Out:
# Analyzing edges from data/test607/
#   Sample rate: 10.0 MSps
#   Pulse freq: 2000 Hz
#   Reference (ch0): 239602 edges
#   Target (ch1): 239602 edges
#   Auto-skipping 0.000s to align channels
#   Starting at: ref idx 0, target idx 1
#
# Matching edges (max delay: 50000ns)...
#   Filtered edges: ref=119801, target=119801
#   Matched: 123803, Rejected: 0
#
# Jitter Statistics (n=119801)
#   Mean:   -5.541 ns
#   Std:    26.427 ns
#   Min:    -96.174 ns
#   Max:    72.535 ns
#   P50:    ±14.793 ns
#   P95:    ±54.924 ns
#   P99:    ±70.232 ns
#   P99.9:  ±79.931 ns
#
# Saved 119801 delays to data/test607/delays.bin
#
# Period Analysis:
#   Channel A: Period: 499.995 ± 0.011 µs (2000.021986 Hz, +11.0 ppm)
#   Channel B: Period: 499.995 ± 0.010 µs (2000.021987 Hz, +11.0 ppm)
#   Frequency skew: +0.000 ppm (+0.1 ns/s)
# Plots saved to data/test607/
# Open data/test607/report.html in browser for full report
