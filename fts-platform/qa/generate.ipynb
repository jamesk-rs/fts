# %% [markdown]
# * This notebook contains TX-side generator commands for demo 3b
# * See capture-analyze.ipynb notebook for matching commands on RX side

# %% [markdown]
# ## TEST 30 - VALIDATE NOSYNC P0 J0

# %%
src/cli.py generate --no-mimo
# Out:
# Generating 50% duty cycle square wave:
#   Pulse freq:  2.0 kHz
#   Phase shift: 0 ns
#   Jitter std:  0 ns
#   Amplitude:   1.0
#   Duration:    indefinite (Ctrl+C to stop)
#   MIMO clock:  False
# Connecting to TX USRP at 192.168.10.3...
# [INFO] [UHD] linux; GNU C++ version 13.2.0; Boost_108300; UHD_4.6.0.0+ds1-5.1ubuntu0.24.04.1
# [INFO] [USRP2] Opening a USRP2/N-Series device...
# [INFO] [USRP2] Current recv frame size: 1472 bytes
# [INFO] [USRP2] Current send frame size: 1472 bytes
#   Sample rate: 10.0 MSps
#   Frequency: 0.0 MHz
# Transmitting 10,000,000 samples...
#   Repeating until Ctrl+C

# %% [markdown]
# ## TEST 31 - VALIDATE P0 J0

# %%
src/cli.py generate
# Out:
# Generating 50% duty cycle square wave:
#   Pulse freq:  2.0 kHz
#   Phase shift: 0 ns
#   Jitter std:  0 ns
#   Amplitude:   1.0
#   Duration:    indefinite (Ctrl+C to stop)
#   MIMO clock:  True
# Connecting to TX USRP at 192.168.10.3...
# [INFO] [UHD] linux; GNU C++ version 13.2.0; Boost_108300; UHD_4.6.0.0+ds1-5.1ubuntu0.24.04.1
# [INFO] [USRP2] Opening a USRP2/N-Series device...
# [INFO] [USRP2] Current recv frame size: 1472 bytes
# [INFO] [USRP2] Current send frame size: 1472 bytes
#   Clock source: mimo
#   Time source: mimo
#   Sample rate: 10.0 MSps
#   Frequency: 0.0 MHz
# Transmitting 10,000,000 samples...
#   Repeating until Ctrl+C
#
# Stopping...
# TX complete.
# Done.

# %% [markdown]
# ## TEST 32 - VALIDATE P1000 J250

# %%
src/cli.py generate -p 1000 -j 250
# Out:
# Generating 50% duty cycle square wave:
#   Pulse freq:  2.0 kHz
#   Phase shift: 1000.0 ns
#   Jitter std:  250.0 ns
#   Amplitude:   1.0
#   Duration:    indefinite (Ctrl+C to stop)
#   MIMO clock:  True
# Connecting to TX USRP at 192.168.10.3...
# [INFO] [UHD] linux; GNU C++ version 11.2.0; Boost_107400; UHD_4.1.0.5-3
# [INFO] [USRP2] Opening a USRP2/N-Series device...
# [INFO] [USRP2] Current recv frame size: 1472 bytes
# [INFO] [USRP2] Current send frame size: 1472 bytes
#   Clock source: mimo
#   Time source: mimo
#   Sample rate: 10.0 MSps
#   Frequency: 0.0 MHz
# Transmitting 10,000,000 samples...
#   Repeating until Ctrl+C

# %% [markdown]
# ## TEST 33 & 34 - VALIDATE P-20 J20

# %%
src/cli.py generate -p -20 -j 20
# Out:
# Generating 50% duty cycle square wave:
#   Pulse freq:  2.0 kHz
#   Phase shift: -20.0 ns
#   Jitter std:  20.0 ns
#   Amplitude:   1.0
#   Duration:    indefinite (Ctrl+C to stop)
#   MIMO clock:  True
# Connecting to TX USRP at 192.168.10.3...
# [INFO] [UHD] linux; GNU C++ version 11.2.0; Boost_107400; UHD_4.1.0.5-3
# [INFO] [USRP2] Opening a USRP2/N-Series device...
# [INFO] [USRP2] Current recv frame size: 1472 bytes
# [INFO] [USRP2] Current send frame size: 1472 bytes
#   Clock source: mimo
#   Time source: mimo
#   Sample rate: 10.0 MSps
#   Frequency: 0.0 MHz
# Transmitting 10,000,000 samples...
#   Repeating until Ctrl+C
