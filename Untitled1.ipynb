# %%
bin/idf build flash monitor all-slaves
# Out:
# ========== SLAVE FIRMWARE ==========
# Building slave firmware...
# Executing action: all (aliases: build)
# Running ninja in directory /home/abb/Documents/dvp/fts/build_slave
# Executing "ninja all"...
# [0/1] Re-running CMake...
# -- Minimal build - ON
# -- Building ESP-IDF components for target esp32s3
# NOTICE: Using component placed at /home/abb/esp/esp-idf/examples/system/console/advanced/components/cmd_nvs for dependency "cmd_nvs", specified in /home/abb/Documents/dvp/fts/main/idf_component.yml
# NOTICE: Using component placed at /home/abb/esp/esp-idf/examples/system/console/advanced/components/cmd_system for dependency "cmd_system", specified in /home/abb/Documents/dvp/fts/main/idf_component.yml
# NOTICE: Using component placed at /home/abb/esp/esp-idf/examples/system/console/advanced/components/cmd_wifi for dependency "cmd_wifi", specified in /home/abb/Documents/dvp/fts/main/idf_component.yml
# NOTICE: Processing 4 dependencies:
# ...

# %%
tmux list-s
# Out:
# [2025-12-16 19:42:01.969086] W (5185) crm: Insufficient samples for regression: 10
#
# M[2025-12-16 19:42:01.969975] FTM,2,0,10,157.8,120.3,209.4,-94,-97,-93
# [2025-12-16 19:42:01.974854] I (5186) ftm: FTM #2: 10/64 entries, RTT avg=157.8ns [120.3,209.4], RSSI avg=-94 [-97, -93]
# [2025-12-16 19:42:03.167083] I (6381) dtr: Alignment request: cycle=356813, ticks=255303545, base_period=20000 FP16 13026
#
# M[2025-12-16 19:42:03.167800] DTC,356813,255303545,1310733026
# [2025-12-16 19:42:03.173415] I (6382) dtr: Alignment feedback: period_ticks=20002 (+2), cycle=356813 (+0)
#
# M[2025-12-16 19:42:03.174049] DTR,356813,0,20002,2
# [2025-12-16 19:42:03.182015] REGR,39,2,88,9.938511078e-06,5.343,1.000000000000,4228921458007,176252854044161
# [2025-12-16 19:42:03.192529] I (6397) crm: Regression: samples=88 (+39), R²=1.000, std=5.343 ns, ppm_lr_m1=9.938511078, ppm_rl_m1=-9.938412305
#
# M[2025-12-16 19:42:03.195168] FTM,2,0,39,102.1,81.2,128.1,-91,-93,-90
# ...

# %%
tmux list-session
# Out:
# 0: 2 windows (created Tue Dec 16 19:37:20 2025) (attached)
